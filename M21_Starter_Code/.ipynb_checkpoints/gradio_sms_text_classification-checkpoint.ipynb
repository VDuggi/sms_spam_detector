# %%
# !pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-4.25.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\mdadv\anaconda\lib\site-packages (from gradio) (22.1.0)
# Collecting altair<6.0,>=4.2.0 (from gradio)
#   Downloading altair-5.3.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting fastapi (from gradio)
#   Downloading fastapi-0.110.1-py3-none-any.whl.metadata (24 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gradio-client==0.15.0 (from gradio)
#   Downloading gradio_client-0.15.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting httpx>=0.24.1 (from gradio)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting huggingface-hub>=0.19.3 (from gradio)
#   Downloading huggingface_hub-0.22.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\mdadv\anaconda\lib\site-packages (from gradio) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in c:\users\mdadv\anaconda\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\mdadv\anaconda\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\mdadv\anaconda\lib\site-packages (from gradio) (3.7.2)
# Requirement already satisfied: numpy~=1.0 in c:\users\mdadv\anaconda\lib\site-packages (from gradio) (1.24.3)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.10.0-cp311-none-win_amd64.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 50.7/50.7 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\mdadv\anaconda\lib\site-packages (from gradio) (23.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\mdadv\anaconda\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\mdadv\anaconda\lib\site-packages (from gradio) (10.0.1)
# Collecting pydantic>=2.0 (from gradio)
#   Downloading pydantic-2.6.4-py3-none-any.whl.metadata (85 kB)
#      ---------------------------------------- 0.0/85.1 kB ? eta -:--:--
#      ---------------------------------------- 85.1/85.1 kB 5.0 MB/s eta 0:00:00
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\mdadv\anaconda\lib\site-packages (from gradio) (6.0.1)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.3.5-py3-none-win_amd64.whl.metadata (24 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.9 in c:\users\mdadv\anaconda\lib\site-packages (from typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\mdadv\anaconda\lib\site-packages (from gradio) (4.10.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.29.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: fsspec in c:\users\mdadv\anaconda\lib\site-packages (from gradio-client==0.15.0->gradio) (2023.4.0)
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.15.0->gradio)
#   Downloading websockets-11.0.3-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\mdadv\anaconda\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in c:\users\mdadv\anaconda\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: anyio in c:\users\mdadv\anaconda\lib\site-packages (from httpx>=0.24.1->gradio) (3.5.0)
# Requirement already satisfied: certifi in c:\users\mdadv\anaconda\lib\site-packages (from httpx>=0.24.1->gradio) (2023.11.17)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in c:\users\mdadv\anaconda\lib\site-packages (from httpx>=0.24.1->gradio) (3.4)
# Requirement already satisfied: sniffio in c:\users\mdadv\anaconda\lib\site-packages (from httpx>=0.24.1->gradio) (1.2.0)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.24.1->gradio)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: filelock in c:\users\mdadv\anaconda\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.9.0)
# Collecting fsspec (from gradio-client==0.15.0->gradio)
#   Downloading fsspec-2024.3.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: requests in c:\users\mdadv\anaconda\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\mdadv\anaconda\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (4.65.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mdadv\anaconda\lib\site-packages (from matplotlib~=3.0->gradio) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\mdadv\anaconda\lib\site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mdadv\anaconda\lib\site-packages (from matplotlib~=3.0->gradio) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mdadv\anaconda\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\mdadv\anaconda\lib\site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mdadv\anaconda\lib\site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mdadv\anaconda\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mdadv\anaconda\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Collecting annotated-types>=0.4.0 (from pydantic>=2.0->gradio)
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.16.3 (from pydantic>=2.0->gradio)
#   Downloading pydantic_core-2.16.3-cp311-none-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\mdadv\anaconda\lib\site-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio) (8.1.7)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in c:\users\mdadv\anaconda\lib\site-packages (from typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio) (0.4.6)
# Collecting shellingham<2.0.0,>=1.3.0 (from typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich<14.0.0,>=10.11.0 (from typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->gradio)
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\mdadv\anaconda\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\mdadv\anaconda\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.0)
# Requirement already satisfied: six>=1.5 in c:\users\mdadv\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mdadv\anaconda\lib\site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mdadv\anaconda\lib\site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mdadv\anaconda\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mdadv\anaconda\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (1.26.18)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mdadv\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9; sys_platform != "emscripten"->gradio) (0.1.0)
# Downloading gradio-4.25.0-py3-none-any.whl (17.1 MB)
#    ---------------------------------------- 0.0/17.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/17.1 MB 10.7 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.8/17.1 MB 18.5 MB/s eta 0:00:01
#    --------- ------------------------------ 3.9/17.1 MB 27.5 MB/s eta 0:00:01
#    ------------- -------------------------- 5.9/17.1 MB 31.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 7.3/17.1 MB 31.0 MB/s eta 0:00:01
#    --------------------- ------------------ 9.3/17.1 MB 33.2 MB/s eta 0:00:01
#    ------------------------- -------------- 11.1/17.1 MB 38.5 MB/s eta 0:00:01
#    ------------------------------- -------- 13.4/17.1 MB 40.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 15.2/17.1 MB 43.7 MB/s eta 0:00:01
#    ---------------------------------------  16.9/17.1 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------- 17.1/17.1 MB 36.4 MB/s eta 0:00:00
# Downloading gradio_client-0.15.0-py3-none-any.whl (313 kB)
#    ---------------------------------------- 0.0/313.4 kB ? eta -:--:--
#    --------------------------------------- 313.4/313.4 kB 18.9 MB/s eta 0:00:00
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading altair-5.3.0-py3-none-any.whl (857 kB)
#    ---------------------------------------- 0.0/857.8 kB ? eta -:--:--
#    --------------------------------------- 857.8/857.8 kB 27.3 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ---------------------------------------- 0.0/75.6 kB ? eta -:--:--
#    ---------------------------------------- 75.6/75.6 kB 4.4 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.9 kB ? eta -:--:--
#    ---------------------------------------- 77.9/77.9 kB 4.2 MB/s eta 0:00:00
# Downloading huggingface_hub-0.22.2-py3-none-any.whl (388 kB)
#    ---------------------------------------- 0.0/388.9 kB ? eta -:--:--
#    --------------------------------------- 388.9/388.9 kB 23.7 MB/s eta 0:00:00
# Downloading orjson-3.10.0-cp311-none-win_amd64.whl (139 kB)
#    ---------------------------------------- 0.0/139.2 kB ? eta -:--:--
#    ---------------------------------------- 139.2/139.2 kB ? eta 0:00:00
# Downloading pydantic-2.6.4-py3-none-any.whl (394 kB)
#    ---------------------------------------- 0.0/394.9 kB ? eta -:--:--
#    --------------------------------------- 394.9/394.9 kB 24.0 MB/s eta 0:00:00
# Downloading pydantic_core-2.16.3-cp311-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------  1.9/1.9 MB 60.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 39.8 MB/s eta 0:00:00
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading ruff-0.3.5-py3-none-win_amd64.whl (8.5 MB)
#    ---------------------------------------- 0.0/8.5 MB ? eta -:--:--
#    -------- ------------------------------- 1.8/8.5 MB 59.1 MB/s eta 0:00:01
#    ------------------ --------------------- 4.0/8.5 MB 51.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.2/8.5 MB 49.4 MB/s eta 0:00:01
#    ------------------------------------- -- 8.1/8.5 MB 47.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.5/8.5 MB 41.7 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#    ---------------------------------------- 60.8/60.8 kB 3.2 MB/s eta 0:00:00
# Downloading fastapi-0.110.1-py3-none-any.whl (91 kB)
#    ---------------------------------------- 0.0/91.9 kB ? eta -:--:--
#    ---------------------------------------- 91.9/91.9 kB 5.1 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#    ---------------------------------------- 0.0/172.0 kB ? eta -:--:--
#    --------------------------------------- 172.0/172.0 kB 10.1 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#    ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ---------------------------------------- 0.0/240.7 kB ? eta -:--:--
#    --------------------------------------- 240.7/240.7 kB 14.4 MB/s eta 0:00:00
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.9 kB ? eta -:--:--
#    ---------------------------------------- 71.9/71.9 kB 4.1 MB/s eta 0:00:00
# Downloading websockets-11.0.3-cp311-cp311-win_amd64.whl (124 kB)
#    ---------------------------------------- 0.0/124.7 kB ? eta -:--:--
#    ---------------------------------------- 124.7/124.7 kB ? eta 0:00:00
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py): started
#   Building wheel for ffmpy (setup.py): finished with status 'done'
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5607 sha256=092959fb69df8bf8344efea8c17984bbca0f7120dc0e75186f1f5d73d47a7e14
#   Stored in directory: c:\users\mdadv\appdata\local\pip\cache\wheels\55\3c\f2\f6e34046bac0d57c13c7d08123b85872423b89c8f59bafda51
# Successfully built ffmpy
# Installing collected packages: pydub, ffmpy, websockets, tomlkit, shellingham, semantic-version, ruff, python-multipart, pydantic-core, orjson, h11, fsspec, annotated-types, uvicorn, starlette, rich, pydantic, huggingface-hub, httpcore, httpx, fastapi, altair, gradio-client, gradio
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.11.1
#     Uninstalling tomlkit-0.11.1:
#       Successfully uninstalled tomlkit-0.11.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.4.0
#     Uninstalling fsspec-2023.4.0:
#       Successfully uninstalled fsspec-2023.4.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.12
#     Uninstalling pydantic-1.10.12:
#       Successfully uninstalled pydantic-1.10.12
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.17.3
#     Uninstalling huggingface-hub-0.17.3:
#       Successfully uninstalled huggingface-hub-0.17.3
# Successfully installed altair-5.3.0 annotated-types-0.6.0 fastapi-0.110.1 ffmpy-0.3.2 fsspec-2024.3.1 gradio-4.25.0 gradio-client-0.15.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 huggingface-hub-0.22.2 orjson-3.10.0 pydantic-2.6.4 pydantic-core-2.16.3 pydub-0.25.1 python-multipart-0.0.9 rich-13.7.1 ruff-0.3.5 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.37.2 tomlkit-0.12.0 uvicorn-0.29.0 websockets-11.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-cloud-auth 0.1.4 requires pydantic<2.0, but you have pydantic 2.6.4 which is incompatible.
# s3fs 2023.4.0 requires fsspec==2023.4.0, but you have fsspec 2024.3.1 which is incompatible.

# %%
# Import pandas
import pandas as pd
# Import the required dependencies from sklearn
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

# Set the column width to view the text message data.
pd.set_option('max_colwidth', 200)

# Import Gradio
import gradio as gr

# %%
def sms_classification(sms_text_df):
    """
    Perform SMS classification using a pipeline with TF-IDF vectorization and Linear Support Vector Classification.

    Parameters:
    - sms_text_df (pd.DataFrame): DataFrame containing 'text_message' and 'label' columns for SMS classification.

    Returns:
    - text_clf (Pipeline): Fitted pipeline model for SMS classification.

    This function takes a DataFrame with 'text_message' and 'label' columns, splits the data into
    training and testing sets, builds a pipeline with TF-IDF vectorization and Linear Support Vector
    Classification, and fits the model to the training data. 
    The fitted pipeline is returned to make future predictions.
    """
    # Set the features variable to the text message column.
    X = sms_text_df['text_message']
    # Set the target variable to the "label" column.
    y = sms_text_df['label']

    # Split data into training and testing and set the test_size = 33%
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.33, random_state=42)
    # Build a pipeline to transform the test set to compare to the training set.
    text_clf = Pipeline([('tfidf', TfidfVectorizer(stop_words='english')),
                     ('clf', LinearSVC()),
])

    # Fit the model to the transformed training data and return model.
    return text_clf.fit(X_train, y_train)

# %%
# Load the dataset into a DataFrame
text_clf = pd.read_csv('Resources/SMSSpamCollection.csv')
text_clf.head()
# Out:
#   label  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                                                                   text_message
# 0                                              Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1                                                                                                                                Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# 3                                                                                                            U dun say so early hor... U c already then say...
# 4                                                                                                Nah I don't think he goes to usf, he lives around here though

# %%
# Call the sms_classification function with the DataFrame and set the result to the "text_clf" variable
text_clf = sms_classification(text_clf)
# Out:
# C:\Users\mdadv\anaconda\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
# Create a function called `sms_prediction` that takes in the SMS text and predicts the whether the text is "not spam" or "spam". 
# The function should return the SMS message, and say whether the text is "not spam" or "spam".
def sms_prediction(text):
    """
    Predict the spam/ham classification of a given text message using a pre-trained model.

    Parameters:
    - text (str): The text message to be classified.

    Returns:
    - str: A message indicating whether the text message is classified as spam or not.

    This function takes a text message and a pre-trained pipeline model, then predicts the
    spam/ham classification of the text. The result is a message stating whether the text is
    classified as spam or not.
    """
    # Create a variable that will hold the prediction of a new text.
    predicted_text = text_clf.predict([text])
    # Using a conditional if the prediction is "ham" return the message:
    # f'The text message: "{text}", is not spam.' Else, return f'The text message: "{text}", is spam.'
    if predicted_text[0] == 'ham':
        return f'The text message: "{text}", is not spam.',
    elif predicted_text[0] == 'spam': 
        return f'The text message: "{text}", is spam.',
    else:
        return 'Error: Unable to classify the text message.'

# %%
# Create a sms_app that takes a textbox for the inputs and has a textbox for the output.  
# Povide labels for each textbox. 
interface = gr.Interface(fn=sms_prediction, 
                         inputs=gr.Textbox(label="Enter your text message"), 
                         outputs=gr.Textbox(label="Prediction"))
    
# Launch the app.
interface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Test the following text messages.
#
# ---
#
# 1. You are a lucky winner of $5000!
# 2. You won 2 free tickets to the Super Bowl.
# 3. You won 2 free tickets to the Super Bowl text us to claim your prize.
# 4. Thanks for registering. Text 4343 to receive free updates on medicare.
